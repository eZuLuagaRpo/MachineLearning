# %% [markdown]
# # 🧠 Taller Final Integrador — Clustering aplicado a escenarios reales
#
# Este notebook corresponde al **taller final integrador** del curso.
#
# ## Reglas de trabajo
# 1. **Antes de cada bloque de código** debes explicar qué vas a hacer.
# 2. **Dentro del código** debes comentar cada línea o sección importante.
# 3. **Después de cada bloque** debes escribir una interpretación clara de lo observado.
# 4. No basta con que el código funcione: debes **justificar decisiones y defender resultados**.
#
# ## Objetivo general
# Aplicar y comparar algoritmos de clustering (**K-Means** y **Mean Shift**) sobre datos reales o imágenes, interpretar sus resultados y proponer un uso práctico en un contexto profesional.

# %% [markdown]
# ## 1. Información del equipo
#
# Completa esta sección antes de empezar.

# %%
# Integrantes del grupo:
# 1.
# 2.
# 3.

# Dataset o imagen seleccionada:
# Tipo de problema:
# Contexto real que desean analizar:

# %% [markdown]
# ## 2. Entendimiento del problema
#
# En esta sección debes explicar:
#
# - ¿Qué es clustering?
# - ¿Por qué este problema puede resolverse con aprendizaje no supervisado?
# - ¿Qué valor tendría encontrar grupos o estructuras ocultas en estos datos?

# %%
# Usa esta celda si quieres organizar tus ideas previas antes de redactar.

# %% [markdown]
# ### Interpretación
#
# Redacta aquí tu explicación conceptual del problema y la justificación del uso de clustering.

# %% [markdown]
# ## 3. Importar librerías
#
# En este bloque debes cargar las librerías necesarias para:
# - análisis de datos
# - visualización
# - clustering
# - métricas de evaluación
# - tratamiento de imágenes (si aplica)

# %%
# Importa aquí las librerías necesarias.
# Ejemplo:
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# from sklearn.cluster import KMeans, MeanShift
# from sklearn.metrics import silhouette_score

# %% [markdown]
# ### Interpretación
#
# Explica por qué son necesarias las librerías que importaste y qué rol cumplen en tu solución.

# %% [markdown]
# ## 4. Carga de datos
#
# En este bloque debes cargar el dataset o la imagen que vas a trabajar.

# %%
# Carga aquí tu dataset o imagen.
# Ejemplos:
# df = pd.read_csv("archivo.csv")
# img = plt.imread("imagen.png")

# Muestra una vista inicial:
# df.head()
# o
# plt.imshow(img)

# %% [markdown]
# ### Interpretación
#
# Describe:
# - qué tipo de datos tienes,
# - cuántas observaciones o dimensiones existen,
# - y qué estructura inicial observas.

# %% [markdown]
# ## 5. Exploración inicial
#
# En esta sección debes explorar los datos para entender mejor el problema.
#
# Incluye según corresponda:
# - tipos de variables
# - estadísticos descriptivos
# - visualizaciones
# - revisión de valores faltantes
# - comportamiento visual de la imagen

# %%
# Realiza aquí la exploración inicial.
# Ejemplos:
# df.info()
# df.describe()
# df.isnull().sum()

# o gráficas:
# plt.scatter(...)
# plt.hist(...)
# plt.imshow(...)

# %% [markdown]
# ### Interpretación
#
# Explica qué descubriste en la exploración y cómo eso influye en la elección del algoritmo o en el preprocesamiento.

# %% [markdown]
# ## 6. Preparación de los datos
#
# En este bloque debes dejar listos los datos para clustering.
#
# Dependiendo del caso, puedes:
# - seleccionar variables numéricas
# - escalar
# - reducir dimensiones
# - vectorizar una imagen
# - convertir RGB a HSV

# %%
# Prepara aquí tus datos para clustering.
# Ejemplos:
# X = df.select_dtypes(include=[np.number])

# o en imágenes:
# vectorized = img.reshape((-1, 3))

# %% [markdown]
# ### Interpretación
#
# Justifica las decisiones tomadas:
# - qué variables elegiste,
# - por qué las elegiste,
# - y por qué esta representación es adecuada para clustering.

# %% [markdown]
# ## 7. Aplicación de K-Means
#
# En esta sección debes aplicar K-Means al problema.

# %%
# Aplica aquí K-Means.
# Ejemplo:
# kmeans = KMeans(n_clusters=3, random_state=42)
# kmeans.fit(X)
# labels_kmeans = kmeans.labels_

# %% [markdown]
# ### Interpretación
#
# Explica:
# - qué hizo K-Means,
# - cuántos clusters encontraste,
# - y qué significa cada grupo en términos del problema.

# %% [markdown]
# ## 8. Método del codo
#
# En este bloque debes evaluar varios valores de K para justificar una elección razonable.

# %%
# Aplica aquí el método del codo.
# Ejemplo:
# inertia = []
# K = range(1, 10)
# for k in K:
#     model = KMeans(n_clusters=k, random_state=42)
#     model.fit(X)
#     inertia.append(model.inertia_)

# plt.plot(K, inertia)
# plt.title("Método del codo")
# plt.show()

# %% [markdown]
# ### Interpretación
#
# Explica:
# - qué representa la curva,
# - en qué punto observas el “codo”,
# - y qué valor de K considerarías adecuado.

# %% [markdown]
# ## 9. Silhouette Score
#
# En este bloque debes calcular silhouette score para comparar la calidad de los clusters.

# %%
# Calcula aquí silhouette score.
# Ejemplo:
# score = silhouette_score(X, labels_kmeans)
# print(score)

# %% [markdown]
# ### Interpretación
#
# Explica:
# - qué mide silhouette,
# - si el valor obtenido indica clusters sólidos o ambiguos,
# - y cómo complementa al método del codo.

# %% [markdown]
# ## 10. Visualización de clusters K-Means
#
# En esta sección debes visualizar los clusters generados por K-Means.

# %%
# Visualiza aquí los clusters encontrados.
# Ejemplo:
# plt.scatter(X[:,0], X[:,1], c=labels_kmeans)
# plt.show()

# %% [markdown]
# ### Interpretación
#
# Describe visualmente:
# - si los clusters parecen coherentes,
# - si hay separación clara,
# - y qué limitaciones notas en el resultado.

# %% [markdown]
# ## 11. Aplicación de Mean Shift
#
# En esta sección debes aplicar Mean Shift al mismo problema para compararlo con K-Means.

# %%
# Aplica aquí Mean Shift.
# Ejemplo:
# ms = MeanShift()
# ms.fit(X)
# labels_ms = ms.labels_

# %% [markdown]
# ### Interpretación
#
# Explica:
# - cuántos clusters encontró Mean Shift,
# - en qué se diferencia de K-Means,
# - y qué ventajas o desventajas observas.

# %% [markdown]
# ## 12. Visualización de Mean Shift
#
# En esta sección debes visualizar el resultado de Mean Shift.

# %%
# Visualiza aquí los clusters encontrados por Mean Shift.
# Ejemplo:
# plt.scatter(X[:,0], X[:,1], c=labels_ms)
# plt.show()

# %% [markdown]
# ### Interpretación
#
# Explica si la estructura encontrada por Mean Shift parece:
# - más realista,
# - más fragmentada,
# - o más útil para el problema.

# %% [markdown]
# ## 13. Caso especial: imágenes (solo si aplica)
#
# Si tu problema es de imágenes, incluye aquí:
#
# - segmentación RGB
# - segmentación HSV
# - máscaras de clusters
# - comparación visual

# %%
# Si estás trabajando con imágenes, desarrolla aquí el caso RGB vs HSV.
# Ejemplo:
# clustered_rgb = ...
# clustered_hsv = ...
# máscaras = ...

# %% [markdown]
# ### Interpretación
#
# Explica:
# - qué diferencias viste entre RGB y HSV,
# - cuál representación funcionó mejor,
# - y por qué.

# %% [markdown]
# ## 14. Comparación final entre algoritmos
#
# En esta sección debes comparar K-Means y Mean Shift.

# %%
# Si quieres, puedes construir una tabla resumen.
# Ejemplo:
# comparacion = {
#    "Algoritmo": ["K-Means", "Mean Shift"],
#    "N° clusters": [..., ...],
#    "Ventaja principal": [..., ...]
# }

# %% [markdown]
# ### Interpretación
#
# Responde:
# - ¿Cuál algoritmo funcionó mejor?
# - ¿Por qué?
# - ¿Qué tipo de estructura detectó cada uno?
# - ¿Cuál usarías en un entorno real?

# %% [markdown]
# ## 15. Aplicación real o propuesta de producción
#
# Aquí debes proponer cómo este modelo podría usarse en un entorno real.
#
# Ejemplos:
# - segmentación de clientes
# - agrupación de eventos
# - análisis de imágenes
# - descubrimiento de perfiles de comportamiento

# %%
# Usa esta celda si deseas organizar ideas o construir una tabla de propuesta de valor.

# %% [markdown]
# ### Interpretación
#
# Describe:
# - el caso de uso real,
# - el impacto potencial,
# - y qué necesitarías para llevar esta solución a producción.

# %% [markdown]
# ## 16. Conclusiones
#
# Redacta conclusiones claras y argumentadas.

# %%
# Usa esta celda si quieres dejar apuntes antes de redactar conclusiones.

# %% [markdown]
# ### Conclusiones finales
#
# Debes incluir:
# - qué aprendiste,
# - cuál algoritmo fue más útil,
# - limitaciones del trabajo,
# - posibles mejoras futuras.

# %% [markdown]
# ## 17. Preguntas de cierre
#
# Responde brevemente:
#
# 1. ¿Qué limitaciones tiene K-Means?
# 2. ¿Qué ventajas tiene Mean Shift?
# 3. ¿Por qué el espacio de representación importa en clustering?
# 4. ¿Qué harías diferente si tuvieras más tiempo o más datos?

# %%
# Puedes responder aquí en forma de lista o apoyarte con pequeños análisis si lo deseas.
